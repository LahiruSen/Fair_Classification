# %%
first_time = False

if(first_time):
  from google.colab import drive
  drive.mount('/content/drive')

# %%
folderPath =  'drive/My Drive/University/SEM7/CS4622_Machine_Learning/Project_1/Fair_Classification/'

# %% [markdown]
# # Import Statements

# %%
if(first_time):
  # !pip install geopy
  # !pip install folium
  # !pip install catboost

# %%
from pathlib import Path

import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

import xgboost as xgb

from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.multioutput import MultiOutputClassifier
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score,mean_squared_error,accuracy_score,f1_score
from sklearn import preprocessing

from catboost import CatBoostClassifier

pd.set_option("display.max_columns", 100)

# %% [markdown]
# # Load Dataset

# %%
features_df = pd.read_csv(
    folderPath+"train.csv", 
    index_col="tripid"
)

test_features_df = pd.read_csv(folderPath+"test.csv", 
                               index_col="tripid")

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Flag location Outliers

# %%
print("Range of pickup Longitude is ", (min(test_features_df['pick_lon']),max(test_features_df['pick_lon'])))
print("Range of Pickup Latitude is ", (min(test_features_df['pick_lat']),max(test_features_df['pick_lat'])))
# Out:
# Range of pickup Longitude is  (79.8177, 80.7764)
# Range of Pickup Latitude is  (5.94313, 8.42501)

# %%
boundary={'min_lng':79.818,
              'min_lat':5.94313,
              'max_lng':80.8055, 
              'max_lat':8.42501}

# %%
def flag_location_outlier(dataset, boundary):
  dataset.loc[~((dataset.pick_lon >= boundary['min_lng'] ) & (dataset.pick_lon <= boundary['max_lng']) &
            (dataset.pick_lat >= boundary['min_lat']) & (dataset.pick_lat <= boundary['max_lat']) &
            (dataset.drop_lon >= boundary['min_lng']) & (dataset.drop_lon <= boundary['max_lng']) &
            (dataset.drop_lat >=boundary['min_lat']) & (dataset.drop_lat <= boundary['max_lat'])),'is_outlier_loc']=1
  dataset.loc[((dataset.pick_lon >= boundary['min_lng'] ) & (dataset.pick_lon <= boundary['max_lng']) &
            (dataset.pick_lat >= boundary['min_lat']) & (dataset.pick_lat <= boundary['max_lat']) &
            (dataset.drop_lon >= boundary['min_lng']) & (dataset.drop_lon <= boundary['max_lng']) &
            (dataset.drop_lat >=boundary['min_lat']) & (dataset.drop_lat <= boundary['max_lat'])),'is_outlier_loc']=0
  is_outlier_loc = dataset['is_outlier_loc'].astype(int)
  dataset['is_outlier_loc'] = is_outlier_loc
  return dataset

# %%
features_df = flag_location_outlier(features_df,boundary)
test_features_df = flag_location_outlier(test_features_df,boundary)

# %% [markdown]
# ## Trip Distance/Speed

# %%
def distance(lat1, lon1, lat2, lon2):
    p = 0.017453292519943295 # Pi/180
    a = 0.5 - np.cos((lat2 - lat1) * p)/2 + np.cos(lat1 * p) * np.cos(lat2 * p) * (1 - np.cos((lon2 - lon1) * p)) / 2
    return 0.6213712 * 12742 * np.arcsin(np.sqrt(a)) 

features_df["distance"] =  distance(features_df["pick_lat"],features_df["pick_lon"],features_df["drop_lat"],features_df["drop_lon"])
test_features_df["distance"] =  distance(test_features_df["pick_lat"],test_features_df["pick_lon"],test_features_df["drop_lat"],test_features_df["drop_lon"])

# %% [markdown]
# ## Find mean Values

# %%
features_df['effective_fare'] = features_df['fare'] - features_df['meter_waiting_fare']
test_features_df['effective_fare'] = test_features_df['fare'] - test_features_df['meter_waiting_fare']

additional_fare_mean = features_df['additional_fare'].mean()
meter_waiting_rate_mean = features_df['meter_waiting_fare'].mean()/features_df['meter_waiting'].mean()
effective_fare_rate = features_df['effective_fare'].mean()/features_df['distance'].mean()
effective_fare_rate_test = test_features_df['effective_fare'].mean()/test_features_df['distance'].mean()

# %% [markdown]
# ## Fill null train set

# %% [markdown]
# ### Seperate correct/incorrect

# %%
features_df_correct = features_df[features_df.label=='correct']
features_df_incorrect = features_df[features_df.label=='incorrect']

# %% [markdown]
# ### Fill Null Seperately

# %%
features_df_correct['meter_waiting'] = features_df_correct['meter_waiting'].fillna(features_df_correct['meter_waiting'].mean())
features_df_incorrect['meter_waiting'] = features_df_incorrect['meter_waiting'].fillna(features_df_incorrect['meter_waiting'].mean())

features_df_correct['meter_waiting_fare'] = features_df_correct['meter_waiting_fare'].fillna(features_df_correct['meter_waiting_fare'].mean())
features_df_incorrect['meter_waiting_fare'] = features_df_incorrect['meter_waiting_fare'].fillna(features_df_incorrect['meter_waiting_fare'].mean())

features_df_correct['fare'] = features_df_correct['fare'].fillna(features_df_correct['distance']*effective_fare_rate+features_df_correct['additional_fare']+features_df_correct['meter_waiting_fare'])
features_df_incorrect['fare'] = features_df_incorrect['fare'].fillna(features_df_incorrect['distance']*effective_fare_rate_test+features_df_incorrect['additional_fare']+features_df_incorrect['meter_waiting_fare'])

# %% [markdown]
# ### Concat correct/Incorrect

# %%
features_df = pd.concat([features_df_correct,features_df_incorrect],sort=True)

# %% [markdown]
# ### Fill null commonly

# %%
features_df['additional_fare'] = features_df['additional_fare'].fillna(features_df['additional_fare'].mode().iloc[0])

features_df["pickup_time"] = pd.to_datetime(features_df["pickup_time"],errors = "coerce")
features_df["drop_time"] = pd.to_datetime(features_df["drop_time"],errors = "coerce")
features_df['duration'] = features_df['duration'].fillna((features_df['drop_time'] - features_df['pickup_time']).astype('timedelta64[s]'))

# %% [markdown]
# ##Fill Null if Any remaining

# %%
features_df = features_df.fillna(features_df.mean())
test_features_df = test_features_df.fillna(test_features_df.mean())

# %% [markdown]
# ## Remove Duplicates

# %%
features_df = features_df.drop_duplicates()

# %% [markdown]
# ## Flag Outliers

# %%
mean, std  =features_df.fare.mean() , features_df.fare.std()
features_df['fare_outlier'] = features_df['fare'].apply(lambda x: 0 if ((np.abs(x-mean) <= (3*std)) or x<=0 or x is None) else 1)
test_features_df['fare_outlier'] = test_features_df['fare'].apply(lambda x: 0 if ((np.abs(x-mean) <= (3*std)) or x<=0 or x is None ) else 1)

print (features_df[features_df.fare_outlier == 1].shape[0])
# Out:
# 88

# %% [markdown]
# ## Set features for Time/Duration

# %%
features_df["pickup_time"] = pd.to_datetime(features_df["pickup_time"],errors = "coerce")
features_df["drop_time"] = pd.to_datetime(features_df["drop_time"],errors = "coerce")
features_df["pickup_time_hour"] = features_df["pickup_time"].dt.hour
features_df["pickup_time_minute"] = features_df["pickup_time"].dt.minute
features_df["drop_time_hour"] =features_df["drop_time"].dt.hour
features_df["drop_time_minute"] =features_df["drop_time"].dt.minute
features_df["pickup_time_day"] = features_df["pickup_time"].dt.day
features_df["drop_time_day"] = features_df["drop_time"].dt.day
features_df["effective_time"] = features_df["duration"]-features_df["meter_waiting"]

test_features_df["pickup_time"] = pd.to_datetime(test_features_df["pickup_time"],errors = "coerce")
test_features_df["drop_time"] = pd.to_datetime(test_features_df["drop_time"],errors = "coerce")
test_features_df["pickup_time_hour"] = test_features_df["pickup_time"].dt.hour
test_features_df["pickup_time_minute"] = test_features_df["pickup_time"].dt.minute
test_features_df["drop_time_hour"] =test_features_df["drop_time"].dt.hour
test_features_df["drop_time_minute"] =test_features_df["drop_time"].dt.minute
test_features_df["pickup_time_day"] = test_features_df["pickup_time"].dt.day
test_features_df["drop_time_day"] = test_features_df["drop_time"].dt.day
test_features_df["effective_time"] = test_features_df["duration"]-test_features_df["meter_waiting"]

# %% [markdown]
# ## Speed

# %%
features_df['speed'] = features_df['distance']/features_df["effective_time"]
test_features_df['speed'] = test_features_df['distance']/test_features_df["effective_time"]

# %% [markdown]
# ## Fare

# %%
features_df['meter_waiting_fare_diff'] = features_df['meter_waiting_fare'] - features_df['meter_waiting']*meter_waiting_rate_mean
features_df['effective_duration'] = features_df['duration'] - features_df['meter_waiting']
features_df['fare_mean'] = features_df['effective_fare']/features_df['effective_duration']
features_df['calculated_fare'] = features_df['distance']*effective_fare_rate + features_df['meter_waiting']*meter_waiting_rate_mean + additional_fare_mean

test_features_df['meter_waiting_fare_diff'] = test_features_df['meter_waiting_fare'] - test_features_df['meter_waiting']*meter_waiting_rate_mean
test_features_df['effective_duration'] = test_features_df['duration'] - test_features_df['meter_waiting']
test_features_df['fare_mean'] = test_features_df['effective_fare']/test_features_df['effective_duration']
test_features_df['calculated_fare'] = test_features_df['distance']*effective_fare_rate + test_features_df['meter_waiting']*meter_waiting_rate_mean + additional_fare_mean

# %% [markdown]
# ## Seperate features/Label

# %%
y= features_df["label"]
y =y.replace(to_replace="correct",value=1)
y =y.replace(to_replace="incorrect",value=0)

X = features_df.drop(columns=["label"], axis=1)

# %%
# X.describe()
test_features_df.isnull().sum(axis = 0)
# Out:
# additional_fare              0
# duration                     0
# meter_waiting                0
# meter_waiting_fare           0
# meter_waiting_till_pickup    0
# pickup_time                  0
# drop_time                    0
# pick_lat                     0
# pick_lon                     0
# drop_lat                     0
# drop_lon                     0
# fare                         0
# is_outlier_loc               0
# distance                     0
# effective_fare               0
# fare_outlier                 0
# pickup_time_hour             0
# pickup_time_minute           0
# drop_time_hour               0
# drop_time_minute             0
# pickup_time_day              0
# drop_time_day                0
# effective_time               0
# speed                        1
# meter_waiting_fare_diff      0
# effective_duration           0
# fare_mean                    1
# calculated_fare              0
# dtype: int64

# %% [markdown]
# ## Set Categorical Variable

# %%
column_titles = []
for col in X.columns: 
    column_titles.append(col)

test_features_df=test_features_df.reindex(columns=column_titles)

# %%
categorical_var = ['is_outlier_loc','fare_outlier']
categorical_var_indices = [X.columns.get_loc(c) for c in categorical_var]

# %% [markdown]
# ## Drop Columns

# %% [markdown]
# ## Set Train/Test

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
print("Number of records in training data ",X_train.shape[0])
print("Number of records in validation data ",X_test.shape[0])
# Out:
# Number of records in training data  13737
# Number of records in validation data  3435

# %% [markdown]
# # Classifiers

# %% [markdown]
# ## Catboost

# %%
model = CatBoostClassifier(iterations=100000, 
                          #  cat_features=categorical_var_indices, 
                          #  task_type="GPU",
                           devices='0:1',
                          nan_mode='Max',
                          eval_metric = 'F1')
# model.fit(X_train,
#           y_train,
#           verbose=True,plot=False, eval_set = (X_test,y_test))

# %%
print(model.get_best_iteration())
# Out:
# None

# %%
predictions = model.predict(X_test)

predictions = [round(value) for value in predictions]
np.unique(predictions , return_counts=True)

# %%
accuracy = accuracy_score(y_test, predictions)
f1_macro = f1_score(y_test, predictions, average='macro')
f1_binary = f1_score(y_test, predictions, average='binary')
print("Accuracy: %.2f%%" % (accuracy * 100.0))
print("Macro F1: %.2f%%" % (f1_macro * 100.0))
print("Binary F1: %.2f%%" % (f1_binary * 100.0))

# %% [markdown]
# filled all null_1227 epochs
# Accuracy: 96.13%
# Macro F1: 88.09%
# Binary F1: 97.87%
#
# 11_P_Original_100000ep_with_newest_features_removed_hardcoded
# Accuracy: 96.22%
# Macro F1: 88.44%
# Binary F1: 97.92%
# Subission score = 98.154%
#
# 9_P_Original_100000ep_with_newes_features shrink to best model
# Accuracy: 96.22%
# Macro F1: 88.44%
# Binary F1: 97.92%
#
# After fixing major issue 460/6000 epochs with cat
# Accuracy: 96.16%
# Macro F1: 87.84%
# Binary F1: 97.90%
#
# 6_P_Original_100000Epochs_all_dataset_with_catVar_Submmit
# Accuracy: 98.69%
# Macro F1: 96.33%
# Binary F1: 99.27%
#
# Piyumal Model - 1000 epochs_Splited_data_with_cat_var
# Accuracy: 96.10%
# Macro F1: 87.54%
# Binary F1: 97.87%
#
# Piyumal Model - 100000 epochs(5290)_AllData
# Accuracy: 98.92%
# Macro F1: 96.67%
# Binary F1: 99.41%
#
# Piyumal Model - 100000 epochs(5290)
# Accuracy: 96.42%
# Macro F1: 88.61%
# Binary F1: 98.04%
# Submission_Score : 0.97863
#
# Piyumal Model - 100000 epochs(5290)
# Accuracy: 96.42%
# Macro F1: 88.61%
# Binary F1: 98.04%
#
# Piyumal Model - 1000 epochs
# Accuracy: 95.90%
# Macro F1: 86.83%
# Binary F1: 97.76%
#
# Accuracy: 95.02%
# Macro F1: 84.69%
# Binary F1: 97.27%
#
# Add fare rate
# Accuracy: 95.87%
# Macro F1: 86.15%
# Binary F1: 97.75%
#
# removed fare outlier
# Accuracy: 94.97%
# Macro F1: 83.32%
# Binary F1: 97.26%
#
# Accuracy: 95.14%
# Macro F1: 84.35%
# Binary F1: 97.34%

# %% [markdown]
# # Save Predictions

# %%
model_new = model
model_new.fit(X,
          y,
          verbose=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# 95001:	learn: 0.9931065	total: 20m 1s	remaining: 1m 3s
# 95002:	learn: 0.9931065	total: 20m 1s	remaining: 1m 3s
# 95003:	learn: 0.9931065	total: 20m 1s	remaining: 1m 3s
# 95004:	learn: 0.9931065	total: 20m 1s	remaining: 1m 3s
# 95005:	learn: 0.9931065	total: 20m 1s	remaining: 1m 3s
# 95006:	learn: 0.9931065	total: 20m 1s	remaining: 1m 3s
# 95007:	learn: 0.9931065	total: 20m 1s	remaining: 1m 3s
# 95008:	learn: 0.9931065	total: 20m 1s	remaining: 1m 3s
# 95009:	learn: 0.9931065	total: 20m 2s	remaining: 1m 3s
# 95010:	learn: 0.9931065	total: 20m 2s	remaining: 1m 3s
# 95011:	learn: 0.9931065	total: 20m 2s	remaining: 1m 3s
# 95012:	learn: 0.9931065	total: 20m 2s	remaining: 1m 3s
# 95013:	learn: 0.9931065	total: 20m 2s	remaining: 1m 3s
# 95014:	learn: 0.9931065	total: 20m 2s	remaining: 1m 3s
# 95015:	learn: 0.9931065	total: 20m 2s	remaining: 1m 3s
# 95016:	learn: 0.9931065	total: 20m 2s	remaining: 1m 3s
# 95017:	learn: 0.9931065	total: 20m 2s	remaining: 1m 3s
# 95018:	learn: 0.9931065	total: 20m 2s	remaining: 1m 3s
# 95019:	learn: 0.9931065	total: 20m 2s	remaining: 1m 3s
# 95020:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95021:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95022:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95023:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95024:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95025:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95026:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95027:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95028:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95029:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95030:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95031:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95032:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95033:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95034:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95035:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95036:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95037:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95038:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95039:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95040:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95041:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95042:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95043:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95044:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95045:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95046:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95047:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95048:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95049:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95050:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95051:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95052:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95053:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95054:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95055:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95056:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95057:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95058:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95059:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95060:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95061:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95062:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95063:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95064:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95065:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95066:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95067:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95068:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95069:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95070:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95071:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95072:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95073:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95074:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95075:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95076:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95077:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95078:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95079:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95080:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95081:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95082:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95083:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95084:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95085:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95086:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95087:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95088:	learn: 0.9931065	total: 20m 2s	remaining: 1m 2s
# 95089:	learn: 0.9931065	total: 20m 3s	remaining: 1m 2s
# 95090:	learn: 0.9931065	total: 20m 3s	remaining: 1m 2s
# 95091:	learn: 0.9931065	total: 20m 3s	remaining: 1m 2s
# 95092:	learn: 0.9931065	total: 20m 3s	remaining: 1m 2s
# 95093:	learn: 0.9931065	total: 20m 3s	remaining: 1m 2s
# 95094:	learn: 0.9931065	total: 20m 3s	remaining: 1m 2s
# 95095:	learn: 0.9931065	total: 20m 3s	remaining: 1m 2s
# 95096:	learn: 0.9931065	total: 20m 3s	remaining: 1m 2s
# 95097:	learn: 0.9931065	total: 20m 3s	remaining: 1m 2s
# 95098:	learn: 0.9931065	total: 20m 3s	remaining: 1m 2s
# 95099:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95100:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95101:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95102:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95103:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95104:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95105:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95106:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95107:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95108:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95109:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95110:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95111:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95112:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95113:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95114:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95115:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95116:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95117:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95118:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95119:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95120:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95121:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95122:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95123:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95124:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95125:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95126:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95127:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95128:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95129:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95130:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95131:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95132:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95133:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95134:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95135:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95136:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95137:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95138:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95139:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95140:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95141:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95142:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95143:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95144:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95145:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95146:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95147:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95148:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95149:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95150:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95151:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95152:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95153:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95154:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95155:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95156:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95157:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95158:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95159:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95160:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95161:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95162:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95163:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95164:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95165:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95166:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95167:	learn: 0.9931065	total: 20m 3s	remaining: 1m 1s
# 95168:	learn: 0.9931065	total: 20m 4s	remaining: 1m 1s
# 95169:	learn: 0.9931065	total: 20m 4s	remaining: 1m 1s
# 95170:	learn: 0.9931065	total: 20m 4s	remaining: 1m 1s
# 95171:	learn: 0.9931065	total: 20m 4s	remaining: 1m 1s
# 95172:	learn: 0.9931065	total: 20m 4s	remaining: 1m 1s
# 95173:	learn: 0.9931065	total: 20m 4s	remaining: 1m 1s
# 95174:	learn: 0.9931065	total: 20m 4s	remaining: 1m 1s
# 95175:	learn: 0.9931065	total: 20m 4s	remaining: 1m 1s
# 95176:	learn: 0.9931065	total: 20m 4s	remaining: 1m 1s
# 95177:	learn: 0.9931065	total: 20m 4s	remaining: 1m 1s
# 95178:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95179:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95180:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95181:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95182:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95183:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95184:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95185:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95186:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95187:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95188:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95189:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95190:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95191:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95192:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95193:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95194:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95195:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95196:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95197:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95198:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95199:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95200:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95201:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95202:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95203:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95204:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95205:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95206:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95207:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95208:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95209:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95210:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95211:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95212:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95213:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95214:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95215:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95216:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95217:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95218:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95219:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95220:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95221:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95222:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95223:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95224:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95225:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95226:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95227:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95228:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95229:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95230:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95231:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95232:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95233:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95234:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95235:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95236:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95237:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95238:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95239:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95240:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95241:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95242:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95243:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95244:	learn: 0.9931065	total: 20m 4s	remaining: 1m
# 95245:	learn: 0.9931065	total: 20m 5s	remaining: 1m
# 95246:	learn: 0.9931065	total: 20m 5s	remaining: 1m
# 95247:	learn: 0.9931065	total: 20m 5s	remaining: 1m
# 95248:	learn: 0.9931065	total: 20m 5s	remaining: 1m
# 95249:	learn: 0.9931065	total: 20m 5s	remaining: 1m
# 95250:	learn: 0.9931065	total: 20m 5s	remaining: 1m
# 95251:	learn: 0.9931065	total: 20m 5s	remaining: 1m
# 95252:	learn: 0.9931065	total: 20m 5s	remaining: 1m
# 95253:	learn: 0.9931065	total: 20m 5s	remaining: 1m
# 95254:	learn: 0.9931065	total: 20m 5s	remaining: 1m
# 95255:	learn: 0.9931065	total: 20m 5s	remaining: 1m
# 95256:	learn: 0.9931065	total: 20m 5s	remaining: 1m
# 95257:	learn: 0.9931065	total: 20m 5s	remaining: 60s
# 95258:	learn: 0.9931065	total: 20m 5s	remaining: 60s
# 95259:	learn: 0.9931065	total: 20m 5s	remaining: 60s
# 95260:	learn: 0.9931065	total: 20m 5s	remaining: 60s
# 95261:	learn: 0.9931065	total: 20m 5s	remaining: 59.9s
# 95262:	learn: 0.9931065	total: 20m 5s	remaining: 59.9s
# 95263:	learn: 0.9931065	total: 20m 5s	remaining: 59.9s
# 95264:	learn: 0.9931065	total: 20m 5s	remaining: 59.9s
# 95265:	learn: 0.9931065	total: 20m 5s	remaining: 59.9s
# 95266:	learn: 0.9931065	total: 20m 5s	remaining: 59.9s
# 95267:	learn: 0.9931065	total: 20m 5s	remaining: 59.9s
# 95268:	learn: 0.9931065	total: 20m 5s	remaining: 59.9s
# 95269:	learn: 0.9931065	total: 20m 5s	remaining: 59.8s
# 95270:	learn: 0.9931065	total: 20m 5s	remaining: 59.8s
# 95271:	learn: 0.9931065	total: 20m 5s	remaining: 59.8s
# 95272:	learn: 0.9931065	total: 20m 5s	remaining: 59.8s
# 95273:	learn: 0.9931065	total: 20m 5s	remaining: 59.8s
# 95274:	learn: 0.9931065	total: 20m 5s	remaining: 59.8s
# 95275:	learn: 0.9931065	total: 20m 5s	remaining: 59.8s
# 95276:	learn: 0.9931065	total: 20m 5s	remaining: 59.8s
# 95277:	learn: 0.9931065	total: 20m 5s	remaining: 59.7s
# 95278:	learn: 0.9931065	total: 20m 5s	remaining: 59.7s
# 95279:	learn: 0.9931065	total: 20m 5s	remaining: 59.7s
# 95280:	learn: 0.9931065	total: 20m 5s	remaining: 59.7s
# 95281:	learn: 0.9931065	total: 20m 5s	remaining: 59.7s
# 95282:	learn: 0.9931065	total: 20m 5s	remaining: 59.7s
# 95283:	learn: 0.9931065	total: 20m 5s	remaining: 59.7s
# 95284:	learn: 0.9931065	total: 20m 5s	remaining: 59.7s
# 95285:	learn: 0.9931065	total: 20m 5s	remaining: 59.6s
# 95286:	learn: 0.9931065	total: 20m 5s	remaining: 59.6s
# 95287:	learn: 0.9931065	total: 20m 5s	remaining: 59.6s
# 95288:	learn: 0.9931065	total: 20m 5s	remaining: 59.6s
# 95289:	learn: 0.9931065	total: 20m 5s	remaining: 59.6s
# 95290:	learn: 0.9931065	total: 20m 5s	remaining: 59.6s
# 95291:	learn: 0.9931065	total: 20m 5s	remaining: 59.6s
# 95292:	learn: 0.9931065	total: 20m 5s	remaining: 59.5s
# 95293:	learn: 0.9931065	total: 20m 5s	remaining: 59.5s
# 95294:	learn: 0.9931065	total: 20m 5s	remaining: 59.5s
# 95295:	learn: 0.9931065	total: 20m 5s	remaining: 59.5s
# 95296:	learn: 0.9931065	total: 20m 5s	remaining: 59.5s
# 95297:	learn: 0.9931065	total: 20m 5s	remaining: 59.5s
# 95298:	learn: 0.9931065	total: 20m 5s	remaining: 59.5s
# 95299:	learn: 0.9931065	total: 20m 5s	remaining: 59.5s
# 95300:	learn: 0.9931065	total: 20m 5s	remaining: 59.4s
# 95301:	learn: 0.9931065	total: 20m 5s	remaining: 59.4s
# 95302:	learn: 0.9931065	total: 20m 5s	remaining: 59.4s
# 95303:	learn: 0.9931065	total: 20m 5s	remaining: 59.4s
# 95304:	learn: 0.9931065	total: 20m 5s	remaining: 59.4s
# 95305:	learn: 0.9931065	total: 20m 5s	remaining: 59.4s
# 95306:	learn: 0.9931065	total: 20m 5s	remaining: 59.4s
# 95307:	learn: 0.9931065	total: 20m 5s	remaining: 59.4s
# 95308:	learn: 0.9931065	total: 20m 5s	remaining: 59.3s
# 95309:	learn: 0.9931065	total: 20m 5s	remaining: 59.3s
# 95310:	learn: 0.9931065	total: 20m 5s	remaining: 59.3s
# 95311:	learn: 0.9931065	total: 20m 5s	remaining: 59.3s
# 95312:	learn: 0.9931065	total: 20m 5s	remaining: 59.3s
# 95313:	learn: 0.9931065	total: 20m 5s	remaining: 59.3s
# 95314:	learn: 0.9931065	total: 20m 5s	remaining: 59.3s
# 95315:	learn: 0.9931065	total: 20m 5s	remaining: 59.3s
# 95316:	learn: 0.9931065	total: 20m 5s	remaining: 59.2s
# 95317:	learn: 0.9931065	total: 20m 5s	remaining: 59.2s
# 95318:	learn: 0.9931065	total: 20m 5s	remaining: 59.2s
# 95319:	learn: 0.9931065	total: 20m 5s	remaining: 59.2s
# 95320:	learn: 0.9931065	total: 20m 5s	remaining: 59.2s
# 95321:	learn: 0.9931065	total: 20m 5s	remaining: 59.2s
# 95322:	learn: 0.9931065	total: 20m 5s	remaining: 59.2s
# 95323:	learn: 0.9931065	total: 20m 6s	remaining: 59.2s
# 95324:	learn: 0.9931065	total: 20m 6s	remaining: 59.1s
# 95325:	learn: 0.9931065	total: 20m 6s	remaining: 59.1s
# 95326:	learn: 0.9931065	total: 20m 6s	remaining: 59.1s
# 95327:	learn: 0.9931065	total: 20m 6s	remaining: 59.1s
# 95328:	learn: 0.9931065	total: 20m 6s	remaining: 59.1s
# 95329:	learn: 0.9931065	total: 20m 6s	remaining: 59.1s
# 95330:	learn: 0.9931065	total: 20m 6s	remaining: 59.1s
# 95331:	learn: 0.9931065	total: 20m 6s	remaining: 59.1s
# 95332:	learn: 0.9931065	total: 20m 6s	remaining: 59s
# 95333:	learn: 0.9931065	total: 20m 6s	remaining: 59s
# 95334:	learn: 0.9931065	total: 20m 6s	remaining: 59s
# 95335:	learn: 0.9931065	total: 20m 6s	remaining: 59s
# 95336:	learn: 0.9931065	total: 20m 6s	remaining: 59s
# 95337:	learn: 0.9931065	total: 20m 6s	remaining: 59s
# 95338:	learn: 0.9931065	total: 20m 6s	remaining: 59s
# 95339:	learn: 0.9931065	total: 20m 6s	remaining: 59s
# 95340:	learn: 0.9931065	total: 20m 6s	remaining: 58.9s
# 95341:	learn: 0.9931065	total: 20m 6s	remaining: 58.9s
# 95342:	learn: 0.9931065	total: 20m 6s	remaining: 58.9s
# 95343:	learn: 0.9931065	total: 20m 6s	remaining: 58.9s
# 95344:	learn: 0.9931065	total: 20m 6s	remaining: 58.9s
# 95345:	learn: 0.9931065	total: 20m 6s	remaining: 58.9s
# 95346:	learn: 0.9931065	total: 20m 6s	remaining: 58.9s
# 95347:	learn: 0.9931065	total: 20m 6s	remaining: 58.9s
# 95348:	learn: 0.9931065	total: 20m 6s	remaining: 58.8s
# 95349:	learn: 0.9931065	total: 20m 6s	remaining: 58.8s
# 95350:	learn: 0.9931065	total: 20m 6s	remaining: 58.8s
# 95351:	learn: 0.9931065	total: 20m 6s	remaining: 58.8s
# 95352:	learn: 0.9931065	total: 20m 6s	remaining: 58.8s
# 95353:	learn: 0.9931065	total: 20m 6s	remaining: 58.8s
# 95354:	learn: 0.9931065	total: 20m 6s	remaining: 58.8s
# 95355:	learn: 0.9931065	total: 20m 6s	remaining: 58.8s
# 95356:	learn: 0.9931065	total: 20m 6s	remaining: 58.7s
# 95357:	learn: 0.9931065	total: 20m 6s	remaining: 58.7s
# 95358:	learn: 0.9931065	total: 20m 6s	remaining: 58.7s
# 95359:	learn: 0.9931065	total: 20m 6s	remaining: 58.7s
# 95360:	learn: 0.9931065	total: 20m 6s	remaining: 58.7s
# 95361:	learn: 0.9931065	total: 20m 6s	remaining: 58.7s
# 95362:	learn: 0.9931065	total: 20m 6s	remaining: 58.7s
# 95363:	learn: 0.9931065	total: 20m 6s	remaining: 58.7s
# 95364:	learn: 0.9931065	total: 20m 6s	remaining: 58.6s
# 95365:	learn: 0.9931065	total: 20m 6s	remaining: 58.6s
# 95366:	learn: 0.9931065	total: 20m 6s	remaining: 58.6s
# 95367:	learn: 0.9931065	total: 20m 6s	remaining: 58.6s
# 95368:	learn: 0.9931065	total: 20m 6s	remaining: 58.6s
# 95369:	learn: 0.9931065	total: 20m 6s	remaining: 58.6s
# 95370:	learn: 0.9931065	total: 20m 6s	remaining: 58.6s
# 95371:	learn: 0.9931065	total: 20m 6s	remaining: 58.6s
# 95372:	learn: 0.9931065	total: 20m 6s	remaining: 58.5s
# 95373:	learn: 0.9931065	total: 20m 6s	remaining: 58.5s
# 95374:	learn: 0.9931065	total: 20m 6s	remaining: 58.5s
# 95375:	learn: 0.9931065	total: 20m 6s	remaining: 58.5s
# 95376:	learn: 0.9931065	total: 20m 6s	remaining: 58.5s
# 95377:	learn: 0.9931065	total: 20m 6s	remaining: 58.5s
# 95378:	learn: 0.9931065	total: 20m 6s	remaining: 58.5s
# 95379:	learn: 0.9931065	total: 20m 6s	remaining: 58.5s
# 95380:	learn: 0.9931065	total: 20m 6s	remaining: 58.4s
# 95381:	learn: 0.9931065	total: 20m 6s	remaining: 58.4s
# 95382:	learn: 0.9931065	total: 20m 6s	remaining: 58.4s
# 95383:	learn: 0.9931065	total: 20m 6s	remaining: 58.4s
# 95384:	learn: 0.9931065	total: 20m 6s	remaining: 58.4s
# 95385:	learn: 0.9931065	total: 20m 6s	remaining: 58.4s
# 95386:	learn: 0.9931065	total: 20m 6s	remaining: 58.4s
# 95387:	learn: 0.9931065	total: 20m 6s	remaining: 58.3s
# 95388:	learn: 0.9931065	total: 20m 6s	remaining: 58.3s
# 95389:	learn: 0.9931065	total: 20m 6s	remaining: 58.3s
# 95390:	learn: 0.9931065	total: 20m 6s	remaining: 58.3s
# 95391:	learn: 0.9931065	total: 20m 6s	remaining: 58.3s
# 95392:	learn: 0.9931065	total: 20m 6s	remaining: 58.3s
# 95393:	learn: 0.9931065	total: 20m 6s	remaining: 58.3s
# 95394:	learn: 0.9931065	total: 20m 6s	remaining: 58.3s
# 95395:	learn: 0.9931065	total: 20m 6s	remaining: 58.2s
# 95396:	learn: 0.9931065	total: 20m 6s	remaining: 58.2s
# 95397:	learn: 0.9931065	total: 20m 6s	remaining: 58.2s
# 95398:	learn: 0.9931065	total: 20m 6s	remaining: 58.2s
# 95399:	learn: 0.9931065	total: 20m 6s	remaining: 58.2s
# 95400:	learn: 0.9931065	total: 20m 6s	remaining: 58.2s
# 95401:	learn: 0.9931065	total: 20m 7s	remaining: 58.2s
# 95402:	learn: 0.9931065	total: 20m 7s	remaining: 58.2s
# 95403:	learn: 0.9931065	total: 20m 7s	remaining: 58.1s
# 95404:	learn: 0.9931065	total: 20m 7s	remaining: 58.1s
# 95405:	learn: 0.9931065	total: 20m 7s	remaining: 58.1s
# 95406:	learn: 0.9931065	total: 20m 7s	remaining: 58.1s
# 95407:	learn: 0.9931065	total: 20m 7s	remaining: 58.1s
# 95408:	learn: 0.9931065	total: 20m 7s	remaining: 58.1s
# 95409:	learn: 0.9931065	total: 20m 7s	remaining: 58.1s
# 95410:	learn: 0.9931065	total: 20m 7s	remaining: 58.1s
# 95411:	learn: 0.9931065	total: 20m 7s	remaining: 58s
# 95412:	learn: 0.9931065	total: 20m 7s	remaining: 58s
# 95413:	learn: 0.9931065	total: 20m 7s	remaining: 58s
# 95414:	learn: 0.9931065	total: 20m 7s	remaining: 58s
# 95415:	learn: 0.9931065	total: 20m 7s	remaining: 58s
# 95416:	learn: 0.9931065	total: 20m 7s	remaining: 58s
# 95417:	learn: 0.9931065	total: 20m 7s	remaining: 58s
# 95418:	learn: 0.9931065	total: 20m 7s	remaining: 58s
# 95419:	learn: 0.9931065	total: 20m 7s	remaining: 57.9s
# 95420:	learn: 0.9931065	total: 20m 7s	remaining: 57.9s
# 95421:	learn: 0.9931065	total: 20m 7s	remaining: 57.9s
# 95422:	learn: 0.9931065	total: 20m 7s	remaining: 57.9s
# 95423:	learn: 0.9931065	total: 20m 7s	remaining: 57.9s
# 95424:	learn: 0.9931065	total: 20m 7s	remaining: 57.9s
# 95425:	learn: 0.9931065	total: 20m 7s	remaining: 57.9s
# 95426:	learn: 0.9931065	total: 20m 7s	remaining: 57.9s
# 95427:	learn: 0.9931065	total: 20m 7s	remaining: 57.8s
# 95428:	learn: 0.9931065	total: 20m 7s	remaining: 57.8s
# 95429:	learn: 0.9931065	total: 20m 7s	remaining: 57.8s
# 95430:	learn: 0.9931065	total: 20m 7s	remaining: 57.8s
# 95431:	learn: 0.9931065	total: 20m 7s	remaining: 57.8s
# 95432:	learn: 0.9931065	total: 20m 7s	remaining: 57.8s
# 95433:	learn: 0.9931065	total: 20m 7s	remaining: 57.8s
# 95434:	learn: 0.9931065	total: 20m 7s	remaining: 57.8s
# 95435:	learn: 0.9931065	total: 20m 7s	remaining: 57.7s
# 95436:	learn: 0.9931065	total: 20m 7s	remaining: 57.7s
# 95437:	learn: 0.9931065	total: 20m 7s	remaining: 57.7s
# 95438:	learn: 0.9931065	total: 20m 7s	remaining: 57.7s
# 95439:	learn: 0.9931065	total: 20m 7s	remaining: 57.7s
# 95440:	learn: 0.9931065	total: 20m 7s	remaining: 57.7s
# 95441:	learn: 0.9931065	total: 20m 7s	remaining: 57.7s
# 95442:	learn: 0.9931065	total: 20m 7s	remaining: 57.7s
# 95443:	learn: 0.9931065	total: 20m 7s	remaining: 57.6s
# 95444:	learn: 0.9931065	total: 20m 7s	remaining: 57.6s
# 95445:	learn: 0.9931065	total: 20m 7s	remaining: 57.6s
# 95446:	learn: 0.9931065	total: 20m 7s	remaining: 57.6s
# 95447:	learn: 0.9931065	total: 20m 7s	remaining: 57.6s
# 95448:	learn: 0.9931065	total: 20m 7s	remaining: 57.6s
# 95449:	learn: 0.9931065	total: 20m 7s	remaining: 57.6s
# 95450:	learn: 0.9931065	total: 20m 7s	remaining: 57.6s
# 95451:	learn: 0.9931065	total: 20m 7s	remaining: 57.5s
# 95452:	learn: 0.9931065	total: 20m 7s	remaining: 57.5s
# 95453:	learn: 0.9931065	total: 20m 7s	remaining: 57.5s
# 95454:	learn: 0.9931065	total: 20m 7s	remaining: 57.5s
# 95455:	learn: 0.9931065	total: 20m 7s	remaining: 57.5s
# 95456:	learn: 0.9931065	total: 20m 7s	remaining: 57.5s
# 95457:	learn: 0.9931065	total: 20m 7s	remaining: 57.5s
# 95458:	learn: 0.9931065	total: 20m 7s	remaining: 57.5s
# 95459:	learn: 0.9931065	total: 20m 7s	remaining: 57.4s
# 95460:	learn: 0.9931065	total: 20m 7s	remaining: 57.4s
# 95461:	learn: 0.9931065	total: 20m 7s	remaining: 57.4s
# 95462:	learn: 0.9931065	total: 20m 7s	remaining: 57.4s
# 95463:	learn: 0.9931065	total: 20m 7s	remaining: 57.4s
# 95464:	learn: 0.9931065	total: 20m 7s	remaining: 57.4s
# 95465:	learn: 0.9931065	total: 20m 7s	remaining: 57.4s
# 95466:	learn: 0.9931065	total: 20m 7s	remaining: 57.4s
# 95467:	learn: 0.9931065	total: 20m 7s	remaining: 57.3s
# 95468:	learn: 0.9931065	total: 20m 7s	remaining: 57.3s
# 95469:	learn: 0.9931065	total: 20m 7s	remaining: 57.3s
# 95470:	learn: 0.9931065	total: 20m 7s	remaining: 57.3s
# 95471:	learn: 0.9931065	total: 20m 7s	remaining: 57.3s
# 95472:	learn: 0.9931065	total: 20m 7s	remaining: 57.3s
# 95473:	learn: 0.9931065	total: 20m 7s	remaining: 57.3s
# 95474:	learn: 0.9931065	total: 20m 7s	remaining: 57.2s
# 95475:	learn: 0.9931065	total: 20m 7s	remaining: 57.2s
# 95476:	learn: 0.9931065	total: 20m 7s	remaining: 57.2s
# 95477:	learn: 0.9931065	total: 20m 7s	remaining: 57.2s
# 95478:	learn: 0.9931065	total: 20m 7s	remaining: 57.2s
# 95479:	learn: 0.9931065	total: 20m 7s	remaining: 57.2s
# 95480:	learn: 0.9931065	total: 20m 8s	remaining: 57.2s
# 95481:	learn: 0.9931065	total: 20m 8s	remaining: 57.2s
# 95482:	learn: 0.9931065	total: 20m 8s	remaining: 57.1s
# 95483:	learn: 0.9931065	total: 20m 8s	remaining: 57.1s
# 95484:	learn: 0.9931065	total: 20m 8s	remaining: 57.1s
# 95485:	learn: 0.9931065	total: 20m 8s	remaining: 57.1s
# 95486:	learn: 0.9931065	total: 20m 8s	remaining: 57.1s
# 95487:	learn: 0.9931065	total: 20m 8s	remaining: 57.1s
# 95488:	learn: 0.9931065	total: 20m 8s	remaining: 57.1s
# 95489:	learn: 0.9931065	total: 20m 8s	remaining: 57.1s
# 95490:	learn: 0.9931384	total: 20m 8s	remaining: 57s
# 95491:	learn: 0.9931384	total: 20m 8s	remaining: 57s
# 95492:	learn: 0.9931384	total: 20m 8s	remaining: 57s
# 95493:	learn: 0.9931384	total: 20m 8s	remaining: 57s
# 95494:	learn: 0.9931384	total: 20m 8s	remaining: 57s
# 95495:	learn: 0.9931384	total: 20m 8s	remaining: 57s
# 95496:	learn: 0.9931384	total: 20m 8s	remaining: 57s
# 95497:	learn: 0.9931384	total: 20m 8s	remaining: 57s
# 95498:	learn: 0.9931384	total: 20m 8s	remaining: 56.9s
# 95499:	learn: 0.9931384	total: 20m 8s	remaining: 56.9s
# 95500:	learn: 0.9931384	total: 20m 8s	remaining: 56.9s
# 95501:	learn: 0.9931384	total: 20m 8s	remaining: 56.9s
# 95502:	learn: 0.9931384	total: 20m 8s	remaining: 56.9s
# 95503:	learn: 0.9931384	total: 20m 8s	remaining: 56.9s
# 95504:	learn: 0.9931384	total: 20m 8s	remaining: 56.9s
# 95505:	learn: 0.9931384	total: 20m 8s	remaining: 56.9s
# 95506:	learn: 0.9931384	total: 20m 8s	remaining: 56.8s
# 95507:	learn: 0.9931384	total: 20m 8s	remaining: 56.8s
# 95508:	learn: 0.9931384	total: 20m 8s	remaining: 56.8s
# 95509:	learn: 0.9931384	total: 20m 8s	remaining: 56.8s
# 95510:	learn: 0.9931384	total: 20m 8s	remaining: 56.8s
# 95511:	learn: 0.9931384	total: 20m 8s	remaining: 56.8s
# 95512:	learn: 0.9931384	total: 20m 8s	remaining: 56.8s
# 95513:	learn: 0.9931384	total: 20m 8s	remaining: 56.8s
# 95514:	learn: 0.9931384	total: 20m 8s	remaining: 56.7s
# 95515:	learn: 0.9931384	total: 20m 8s	remaining: 56.7s
# 95516:	learn: 0.9931384	total: 20m 8s	remaining: 56.7s
# 95517:	learn: 0.9931384	total: 20m 8s	remaining: 56.7s
# 95518:	learn: 0.9931384	total: 20m 8s	remaining: 56.7s
# 95519:	learn: 0.9931384	total: 20m 8s	remaining: 56.7s
# 95520:	learn: 0.9931384	total: 20m 8s	remaining: 56.7s
# 95521:	learn: 0.9931384	total: 20m 8s	remaining: 56.7s
# 95522:	learn: 0.9931384	total: 20m 8s	remaining: 56.6s
# 95523:	learn: 0.9931384	total: 20m 8s	remaining: 56.6s
# 95524:	learn: 0.9931384	total: 20m 8s	remaining: 56.6s
# 95525:	learn: 0.9931384	total: 20m 8s	remaining: 56.6s
# 95526:	learn: 0.9931384	total: 20m 8s	remaining: 56.6s
# 95527:	learn: 0.9931384	total: 20m 8s	remaining: 56.6s
# 95528:	learn: 0.9931384	total: 20m 8s	remaining: 56.6s
# 95529:	learn: 0.9931384	total: 20m 8s	remaining: 56.6s
# 95530:	learn: 0.9931384	total: 20m 8s	remaining: 56.5s
# 95531:	learn: 0.9931384	total: 20m 8s	remaining: 56.5s
# 95532:	learn: 0.9931384	total: 20m 8s	remaining: 56.5s
# 95533:	learn: 0.9931384	total: 20m 8s	remaining: 56.5s
# 95534:	learn: 0.9931384	total: 20m 8s	remaining: 56.5s
# 95535:	learn: 0.9931384	total: 20m 8s	remaining: 56.5s
# 95536:	learn: 0.9931384	total: 20m 8s	remaining: 56.5s
# 95537:	learn: 0.9931384	total: 20m 8s	remaining: 56.5s
# 95538:	learn: 0.9931384	total: 20m 8s	remaining: 56.4s
# 95539:	learn: 0.9931384	total: 20m 8s	remaining: 56.4s
# 95540:	learn: 0.9931384	total: 20m 8s	remaining: 56.4s
# 95541:	learn: 0.9931384	total: 20m 8s	remaining: 56.4s
# 95542:	learn: 0.9931384	total: 20m 8s	remaining: 56.4s
# 95543:	learn: 0.9931384	total: 20m 8s	remaining: 56.4s
# 95544:	learn: 0.9931384	total: 20m 8s	remaining: 56.4s
# 95545:	learn: 0.9931384	total: 20m 8s	remaining: 56.4s
# 95546:	learn: 0.9931384	total: 20m 8s	remaining: 56.3s
# 95547:	learn: 0.9931384	total: 20m 8s	remaining: 56.3s
# 95548:	learn: 0.9931384	total: 20m 8s	remaining: 56.3s
# 95549:	learn: 0.9931384	total: 20m 8s	remaining: 56.3s
# 95550:	learn: 0.9931384	total: 20m 8s	remaining: 56.3s
# 95551:	learn: 0.9931384	total: 20m 8s	remaining: 56.3s
# 95552:	learn: 0.9931384	total: 20m 8s	remaining: 56.3s
# 95553:	learn: 0.9931384	total: 20m 8s	remaining: 56.3s
# 95554:	learn: 0.9931384	total: 20m 8s	remaining: 56.2s
# 95555:	learn: 0.9931384	total: 20m 8s	remaining: 56.2s
# 95556:	learn: 0.9931384	total: 20m 8s	remaining: 56.2s
# 95557:	learn: 0.9931384	total: 20m 9s	remaining: 56.2s
# 95558:	learn: 0.9931384	total: 20m 9s	remaining: 56.2s
# 95559:	learn: 0.9931384	total: 20m 9s	remaining: 56.2s
# 95560:	learn: 0.9931384	total: 20m 9s	remaining: 56.2s
# 95561:	learn: 0.9931384	total: 20m 9s	remaining: 56.1s
# 95562:	learn: 0.9931384	total: 20m 9s	remaining: 56.1s
# 95563:	learn: 0.9931384	total: 20m 9s	remaining: 56.1s
# 95564:	learn: 0.9931384	total: 20m 9s	remaining: 56.1s
# 95565:	learn: 0.9931384	total: 20m 9s	remaining: 56.1s
# 95566:	learn: 0.9931384	total: 20m 9s	remaining: 56.1s
# 95567:	learn: 0.9931384	total: 20m 9s	remaining: 56.1s
# 95568:	learn: 0.9931384	total: 20m 9s	remaining: 56.1s
# 95569:	learn: 0.9931384	total: 20m 9s	remaining: 56s
# 95570:	learn: 0.9931384	total: 20m 9s	remaining: 56s
# 95571:	learn: 0.9931384	total: 20m 9s	remaining: 56s
# 95572:	learn: 0.9931384	total: 20m 9s	remaining: 56s
# 95573:	learn: 0.9931384	total: 20m 9s	remaining: 56s
# 95574:	learn: 0.9931384	total: 20m 9s	remaining: 56s
# 95575:	learn: 0.9931384	total: 20m 9s	remaining: 56s
# 95576:	learn: 0.9931384	total: 20m 9s	remaining: 56s
# 95577:	learn: 0.9931384	total: 20m 9s	remaining: 55.9s
# 95578:	learn: 0.9931384	total: 20m 9s	remaining: 55.9s
# 95579:	learn: 0.9931384	total: 20m 9s	remaining: 55.9s
# 95580:	learn: 0.9931384	total: 20m 9s	remaining: 55.9s
# 95581:	learn: 0.9931384	total: 20m 9s	remaining: 55.9s
# 95582:	learn: 0.9931384	total: 20m 9s	remaining: 55.9s
# 95583:	learn: 0.9931384	total: 20m 9s	remaining: 55.9s
# 95584:	learn: 0.9931384	total: 20m 9s	remaining: 55.9s
# 95585:	learn: 0.9931384	total: 20m 9s	remaining: 55.8s
# 95586:	learn: 0.9931384	total: 20m 9s	remaining: 55.8s
# 95587:	learn: 0.9931384	total: 20m 9s	remaining: 55.8s
# 95588:	learn: 0.9931384	total: 20m 9s	remaining: 55.8s
# 95589:	learn: 0.9931384	total: 20m 9s	remaining: 55.8s
# 95590:	learn: 0.9931384	total: 20m 9s	remaining: 55.8s
# 95591:	learn: 0.9931384	total: 20m 9s	remaining: 55.8s
# 95592:	learn: 0.9931384	total: 20m 9s	remaining: 55.8s
# 95593:	learn: 0.9931384	total: 20m 9s	remaining: 55.7s
# 95594:	learn: 0.9931384	total: 20m 9s	remaining: 55.7s
# 95595:	learn: 0.9931384	total: 20m 9s	remaining: 55.7s
# 95596:	learn: 0.9931384	total: 20m 9s	remaining: 55.7s
# 95597:	learn: 0.9931384	total: 20m 9s	remaining: 55.7s
# 95598:	learn: 0.9931384	total: 20m 9s	remaining: 55.7s
# 95599:	learn: 0.9931384	total: 20m 9s	remaining: 55.7s
# 95600:	learn: 0.9931384	total: 20m 9s	remaining: 55.7s
# 95601:	learn: 0.9931384	total: 20m 9s	remaining: 55.6s
# 95602:	learn: 0.9931384	total: 20m 9s	remaining: 55.6s
# 95603:	learn: 0.9931384	total: 20m 9s	remaining: 55.6s
# 95604:	learn: 0.9931384	total: 20m 9s	remaining: 55.6s
# 95605:	learn: 0.9931384	total: 20m 9s	remaining: 55.6s
# 95606:	learn: 0.9931384	total: 20m 9s	remaining: 55.6s
# 95607:	learn: 0.9931384	total: 20m 9s	remaining: 55.6s
# 95608:	learn: 0.9931384	total: 20m 9s	remaining: 55.6s
# 95609:	learn: 0.9931384	total: 20m 9s	remaining: 55.5s
# 95610:	learn: 0.9931384	total: 20m 9s	remaining: 55.5s
# 95611:	learn: 0.9931384	total: 20m 9s	remaining: 55.5s
# 95612:	learn: 0.9931384	total: 20m 9s	remaining: 55.5s
# 95613:	learn: 0.9931384	total: 20m 9s	remaining: 55.5s
# 95614:	learn: 0.9931384	total: 20m 9s	remaining: 55.5s
# 95615:	learn: 0.9931384	total: 20m 9s	remaining: 55.5s
# 95616:	learn: 0.9931384	total: 20m 9s	remaining: 55.5s
# 95617:	learn: 0.9931384	total: 20m 9s	remaining: 55.4s
# 95618:	learn: 0.9931384	total: 20m 9s	remaining: 55.4s
# 95619:	learn: 0.9931384	total: 20m 9s	remaining: 55.4s
# 95620:	learn: 0.9931384	total: 20m 9s	remaining: 55.4s
# 95621:	learn: 0.9931384	total: 20m 9s	remaining: 55.4s
# 95622:	learn: 0.9931384	total: 20m 9s	remaining: 55.4s
# 95623:	learn: 0.9931384	total: 20m 9s	remaining: 55.4s
# 95624:	learn: 0.9931384	total: 20m 9s	remaining: 55.4s
# 95625:	learn: 0.9931384	total: 20m 9s	remaining: 55.3s
# 95626:	learn: 0.9931384	total: 20m 9s	remaining: 55.3s
# 95627:	learn: 0.9931384	total: 20m 9s	remaining: 55.3s
# 95628:	learn: 0.9931384	total: 20m 9s	remaining: 55.3s
# 95629:	learn: 0.9931384	total: 20m 9s	remaining: 55.3s
# 95630:	learn: 0.9931384	total: 20m 9s	remaining: 55.3s
# 95631:	learn: 0.9931384	total: 20m 9s	remaining: 55.3s
# 95632:	learn: 0.9931384	total: 20m 9s	remaining: 55.3s
# 95633:	learn: 0.9931384	total: 20m 10s	remaining: 55.2s
# 95634:	learn: 0.9931384	total: 20m 10s	remaining: 55.2s
# 95635:	learn: 0.9931384	total: 20m 10s	remaining: 55.2s
# 95636:	learn: 0.9931384	total: 20m 10s	remaining: 55.2s
# 95637:	learn: 0.9931384	total: 20m 10s	remaining: 55.2s
# 95638:	learn: 0.9931384	total: 20m 10s	remaining: 55.2s
# 95639:	learn: 0.9931384	total: 20m 10s	remaining: 55.2s
# 95640:	learn: 0.9931384	total: 20m 10s	remaining: 55.2s
# 95641:	learn: 0.9931384	total: 20m 10s	remaining: 55.1s
# 95642:	learn: 0.9931384	total: 20m 10s	remaining: 55.1s
# 95643:	learn: 0.9931384	total: 20m 10s	remaining: 55.1s
# 95644:	learn: 0.9931384	total: 20m 10s	remaining: 55.1s
# 95645:	learn: 0.9931384	total: 20m 10s	remaining: 55.1s
# 95646:	learn: 0.9931384	total: 20m 10s	remaining: 55.1s
# 95647:	learn: 0.9931384	total: 20m 10s	remaining: 55.1s
# 95648:	learn: 0.9931384	total: 20m 10s	remaining: 55s
# 95649:	learn: 0.9931384	total: 20m 10s	remaining: 55s
# 95650:	learn: 0.9931384	total: 20m 10s	remaining: 55s
# 95651:	learn: 0.9931384	total: 20m 10s	remaining: 55s
# 95652:	learn: 0.9931384	total: 20m 10s	remaining: 55s
# 95653:	learn: 0.9931384	total: 20m 10s	remaining: 55s
# 95654:	learn: 0.9931384	total: 20m 10s	remaining: 55s
# 95655:	learn: 0.9931384	total: 20m 10s	remaining: 55s
# 95656:	learn: 0.9931384	total: 20m 10s	remaining: 54.9s
# 95657:	learn: 0.9931384	total: 20m 10s	remaining: 54.9s
# 95658:	learn: 0.9931384	total: 20m 10s	remaining: 54.9s
# 95659:	learn: 0.9931384	total: 20m 10s	remaining: 54.9s
# 95660:	learn: 0.9931384	total: 20m 10s	remaining: 54.9s
# 95661:	learn: 0.9931384	total: 20m 10s	remaining: 54.9s
# 95662:	learn: 0.9931384	total: 20m 10s	remaining: 54.9s
# 95663:	learn: 0.9931384	total: 20m 10s	remaining: 54.9s
# 95664:	learn: 0.9931384	total: 20m 10s	remaining: 54.8s
# 95665:	learn: 0.9931384	total: 20m 10s	remaining: 54.8s
# 95666:	learn: 0.9931384	total: 20m 10s	remaining: 54.8s
# 95667:	learn: 0.9931384	total: 20m 10s	remaining: 54.8s
# 95668:	learn: 0.9931384	total: 20m 10s	remaining: 54.8s
# 95669:	learn: 0.9931384	total: 20m 10s	remaining: 54.8s
# 95670:	learn: 0.9931384	total: 20m 10s	remaining: 54.8s
# 95671:	learn: 0.9931384	total: 20m 10s	remaining: 54.8s
# 95672:	learn: 0.9931384	total: 20m 10s	remaining: 54.7s
# 95673:	learn: 0.9931384	total: 20m 10s	remaining: 54.7s
# 95674:	learn: 0.9931384	total: 20m 10s	remaining: 54.7s
# 95675:	learn: 0.9931384	total: 20m 10s	remaining: 54.7s
# 95676:	learn: 0.9931384	total: 20m 10s	remaining: 54.7s
# 95677:	learn: 0.9931384	total: 20m 10s	remaining: 54.7s
# 95678:	learn: 0.9931384	total: 20m 10s	remaining: 54.7s
# 95679:	learn: 0.9931384	total: 20m 10s	remaining: 54.7s
# 95680:	learn: 0.9931384	total: 20m 10s	remaining: 54.6s
# 95681:	learn: 0.9931384	total: 20m 10s	remaining: 54.6s
# 95682:	learn: 0.9931384	total: 20m 10s	remaining: 54.6s
# 95683:	learn: 0.9931384	total: 20m 10s	remaining: 54.6s
# 95684:	learn: 0.9931384	total: 20m 10s	remaining: 54.6s
# 95685:	learn: 0.9931384	total: 20m 10s	remaining: 54.6s
# 95686:	learn: 0.9931384	total: 20m 10s	remaining: 54.6s
# 95687:	learn: 0.9931384	total: 20m 10s	remaining: 54.6s
# 95688:	learn: 0.9931384	total: 20m 10s	remaining: 54.5s
# 95689:	learn: 0.9931384	total: 20m 10s	remaining: 54.5s
# 95690:	learn: 0.9931384	total: 20m 10s	remaining: 54.5s
# 95691:	learn: 0.9931384	total: 20m 10s	remaining: 54.5s
# 95692:	learn: 0.9931384	total: 20m 10s	remaining: 54.5s
# 95693:	learn: 0.9931384	total: 20m 10s	remaining: 54.5s
# 95694:	learn: 0.9931384	total: 20m 10s	remaining: 54.5s
# 95695:	learn: 0.9931384	total: 20m 10s	remaining: 54.5s
# 95696:	learn: 0.9931384	total: 20m 10s	remaining: 54.4s
# 95697:	learn: 0.9931384	total: 20m 10s	remaining: 54.4s
# 95698:	learn: 0.9931384	total: 20m 10s	remaining: 54.4s
# 95699:	learn: 0.9931384	total: 20m 10s	remaining: 54.4s
# 95700:	learn: 0.9931384	total: 20m 10s	remaining: 54.4s
# 95701:	learn: 0.9931384	total: 20m 10s	remaining: 54.4s
# 95702:	learn: 0.9931384	total: 20m 10s	remaining: 54.4s
# 95703:	learn: 0.9931384	total: 20m 10s	remaining: 54.4s
# 95704:	learn: 0.9931384	total: 20m 10s	remaining: 54.3s
# 95705:	learn: 0.9931384	total: 20m 10s	remaining: 54.3s
# 95706:	learn: 0.9931384	total: 20m 10s	remaining: 54.3s
# 95707:	learn: 0.9931384	total: 20m 10s	remaining: 54.3s
# 95708:	learn: 0.9931384	total: 20m 10s	remaining: 54.3s
# 95709:	learn: 0.9931384	total: 20m 11s	remaining: 54.3s
# 95710:	learn: 0.9931384	total: 20m 11s	remaining: 54.3s
# 95711:	learn: 0.9931384	total: 20m 11s	remaining: 54.3s
# 95712:	learn: 0.9931384	total: 20m 11s	remaining: 54.2s
# 95713:	learn: 0.9931384	total: 20m 11s	remaining: 54.2s
# 95714:	learn: 0.9931384	total: 20m 11s	remaining: 54.2s
# 95715:	learn: 0.9931384	total: 20m 11s	remaining: 54.2s
# 95716:	learn: 0.9931384	total: 20m 11s	remaining: 54.2s
# 95717:	learn: 0.9931384	total: 20m 11s	remaining: 54.2s
# 95718:	learn: 0.9931384	total: 20m 11s	remaining: 54.2s
# 95719:	learn: 0.9931384	total: 20m 11s	remaining: 54.2s
# 95720:	learn: 0.9931384	total: 20m 11s	remaining: 54.1s
# 95721:	learn: 0.9931384	total: 20m 11s	remaining: 54.1s
# 95722:	learn: 0.9931384	total: 20m 11s	remaining: 54.1s
# 95723:	learn: 0.9931384	total: 20m 11s	remaining: 54.1s
# 95724:	learn: 0.9931384	total: 20m 11s	remaining: 54.1s
# 95725:	learn: 0.9931384	total: 20m 11s	remaining: 54.1s
# 95726:	learn: 0.9931384	total: 20m 11s	remaining: 54.1s
# 95727:	learn: 0.9931384	total: 20m 11s	remaining: 54.1s
# 95728:	learn: 0.9931384	total: 20m 11s	remaining: 54s
# 95729:	learn: 0.9931384	total: 20m 11s	remaining: 54s
# 95730:	learn: 0.9931384	total: 20m 11s	remaining: 54s
# 95731:	learn: 0.9931384	total: 20m 11s	remaining: 54s
# 95732:	learn: 0.9931384	total: 20m 11s	remaining: 54s
# 95733:	learn: 0.9931384	total: 20m 11s	remaining: 54s
# 95734:	learn: 0.9931384	total: 20m 11s	remaining: 54s
# 95735:	learn: 0.9931384	total: 20m 11s	remaining: 54s
# 95736:	learn: 0.9931384	total: 20m 11s	remaining: 53.9s
# 95737:	learn: 0.9931384	total: 20m 11s	remaining: 53.9s
# 95738:	learn: 0.9931384	total: 20m 11s	remaining: 53.9s
# 95739:	learn: 0.9931384	total: 20m 11s	remaining: 53.9s
# 95740:	learn: 0.9931384	total: 20m 11s	remaining: 53.9s
# 95741:	learn: 0.9931384	total: 20m 11s	remaining: 53.9s
# 95742:	learn: 0.9931384	total: 20m 11s	remaining: 53.9s
# 95743:	learn: 0.9931384	total: 20m 11s	remaining: 53.9s
# 95744:	learn: 0.9931384	total: 20m 11s	remaining: 53.8s
# 95745:	learn: 0.9931384	total: 20m 11s	remaining: 53.8s
# 95746:	learn: 0.9931384	total: 20m 11s	remaining: 53.8s
# 95747:	learn: 0.9931384	total: 20m 11s	remaining: 53.8s
# 95748:	learn: 0.9931384	total: 20m 11s	remaining: 53.8s
# 95749:	learn: 0.9931384	total: 20m 11s	remaining: 53.8s
# 95750:	learn: 0.9931384	total: 20m 11s	remaining: 53.8s
# 95751:	learn: 0.9931384	total: 20m 11s	remaining: 53.7s
# 95752:	learn: 0.9931384	total: 20m 11s	remaining: 53.7s
# 95753:	learn: 0.9931384	total: 20m 11s	remaining: 53.7s
# 95754:	learn: 0.9931384	total: 20m 11s	remaining: 53.7s
# 95755:	learn: 0.9931384	total: 20m 11s	remaining: 53.7s
# 95756:	learn: 0.9931384	total: 20m 11s	remaining: 53.7s
# 95757:	learn: 0.9931384	total: 20m 11s	remaining: 53.7s
# 95758:	learn: 0.9931384	total: 20m 11s	remaining: 53.7s
# 95759:	learn: 0.9931384	total: 20m 11s	remaining: 53.6s
# 95760:	learn: 0.9931384	total: 20m 11s	remaining: 53.6s
# 95761:	learn: 0.9931384	total: 20m 11s	remaining: 53.6s
# 95762:	learn: 0.9931384	total: 20m 11s	remaining: 53.6s
# 95763:	learn: 0.9931384	total: 20m 11s	remaining: 53.6s
# 95764:	learn: 0.9931384	total: 20m 11s	remaining: 53.6s
# 95765:	learn: 0.9931384	total: 20m 11s	remaining: 53.6s
# 95766:	learn: 0.9931384	total: 20m 11s	remaining: 53.6s
# 95767:	learn: 0.9931384	total: 20m 11s	remaining: 53.5s
# 95768:	learn: 0.9931384	total: 20m 11s	remaining: 53.5s
# 95769:	learn: 0.9931384	total: 20m 11s	remaining: 53.5s
# 95770:	learn: 0.9931384	total: 20m 11s	remaining: 53.5s
# 95771:	learn: 0.9931384	total: 20m 11s	remaining: 53.5s
# 95772:	learn: 0.9931384	total: 20m 11s	remaining: 53.5s
# 95773:	learn: 0.9931384	total: 20m 11s	remaining: 53.5s
# 95774:	learn: 0.9931384	total: 20m 11s	remaining: 53.5s
# 95775:	learn: 0.9931384	total: 20m 11s	remaining: 53.4s
# 95776:	learn: 0.9931384	total: 20m 11s	remaining: 53.4s
# 95777:	learn: 0.9931384	total: 20m 11s	remaining: 53.4s
# 95778:	learn: 0.9931384	total: 20m 11s	remaining: 53.4s
# 95779:	learn: 0.9931384	total: 20m 11s	remaining: 53.4s
# 95780:	learn: 0.9931384	total: 20m 11s	remaining: 53.4s
# 95781:	learn: 0.9931384	total: 20m 11s	remaining: 53.4s
# 95782:	learn: 0.9931384	total: 20m 11s	remaining: 53.4s
# 95783:	learn: 0.9931384	total: 20m 11s	remaining: 53.3s
# 95784:	learn: 0.9931384	total: 20m 11s	remaining: 53.3s
# 95785:	learn: 0.9931384	total: 20m 11s	remaining: 53.3s
# 95786:	learn: 0.9931384	total: 20m 11s	remaining: 53.3s
# 95787:	learn: 0.9931384	total: 20m 12s	remaining: 53.3s
# 95788:	learn: 0.9931384	total: 20m 12s	remaining: 53.3s
# 95789:	learn: 0.9931384	total: 20m 12s	remaining: 53.3s
# 95790:	learn: 0.9931384	total: 20m 12s	remaining: 53.3s
# 95791:	learn: 0.9931384	total: 20m 12s	remaining: 53.2s
# 95792:	learn: 0.9931384	total: 20m 12s	remaining: 53.2s
# 95793:	learn: 0.9931384	total: 20m 12s	remaining: 53.2s
# 95794:	learn: 0.9931384	total: 20m 12s	remaining: 53.2s
# 95795:	learn: 0.9931384	total: 20m 12s	remaining: 53.2s
# 95796:	learn: 0.9931384	total: 20m 12s	remaining: 53.2s
# 95797:	learn: 0.9931384	total: 20m 12s	remaining: 53.2s
# 95798:	learn: 0.9931384	total: 20m 12s	remaining: 53.2s
# 95799:	learn: 0.9931384	total: 20m 12s	remaining: 53.1s
# 95800:	learn: 0.9931384	total: 20m 12s	remaining: 53.1s
# 95801:	learn: 0.9931384	total: 20m 12s	remaining: 53.1s
# 95802:	learn: 0.9931384	total: 20m 12s	remaining: 53.1s
# 95803:	learn: 0.9931384	total: 20m 12s	remaining: 53.1s
# 95804:	learn: 0.9931384	total: 20m 12s	remaining: 53.1s
# 95805:	learn: 0.9931384	total: 20m 12s	remaining: 53.1s
# 95806:	learn: 0.9931384	total: 20m 12s	remaining: 53.1s
# 95807:	learn: 0.9931384	total: 20m 12s	remaining: 53s
# 95808:	learn: 0.9931384	total: 20m 12s	remaining: 53s
# 95809:	learn: 0.9931384	total: 20m 12s	remaining: 53s
# 95810:	learn: 0.9931384	total: 20m 12s	remaining: 53s
# 95811:	learn: 0.9931384	total: 20m 12s	remaining: 53s
# 95812:	learn: 0.9931384	total: 20m 12s	remaining: 53s
# 95813:	learn: 0.9931384	total: 20m 12s	remaining: 53s
# 95814:	learn: 0.9931384	total: 20m 12s	remaining: 53s
# 95815:	learn: 0.9931384	total: 20m 12s	remaining: 52.9s
# 95816:	learn: 0.9931384	total: 20m 12s	remaining: 52.9s
# 95817:	learn: 0.9931384	total: 20m 12s	remaining: 52.9s
# 95818:	learn: 0.9931384	total: 20m 12s	remaining: 52.9s
# 95819:	learn: 0.9931384	total: 20m 12s	remaining: 52.9s
# 95820:	learn: 0.9931384	total: 20m 12s	remaining: 52.9s
# 95821:	learn: 0.9931384	total: 20m 12s	remaining: 52.9s
# 95822:	learn: 0.9931384	total: 20m 12s	remaining: 52.9s
# 95823:	learn: 0.9931384	total: 20m 12s	remaining: 52.8s
# 95824:	learn: 0.9931384	total: 20m 12s	remaining: 52.8s
# 95825:	learn: 0.9931384	total: 20m 12s	remaining: 52.8s
# 95826:	learn: 0.9931384	total: 20m 12s	remaining: 52.8s
# 95827:	learn: 0.9931384	total: 20m 12s	remaining: 52.8s
# 95828:	learn: 0.9931384	total: 20m 12s	remaining: 52.8s
# 95829:	learn: 0.9931384	total: 20m 12s	remaining: 52.8s
# 95830:	learn: 0.9931384	total: 20m 12s	remaining: 52.8s
# 95831:	learn: 0.9931384	total: 20m 12s	remaining: 52.7s
# 95832:	learn: 0.9931384	total: 20m 12s	remaining: 52.7s
# 95833:	learn: 0.9931384	total: 20m 12s	remaining: 52.7s
# 95834:	learn: 0.9931384	total: 20m 12s	remaining: 52.7s
# 95835:	learn: 0.9931384	total: 20m 12s	remaining: 52.7s
# 95836:	learn: 0.9931384	total: 20m 12s	remaining: 52.7s
# 95837:	learn: 0.9931384	total: 20m 12s	remaining: 52.7s
# 95838:	learn: 0.9931384	total: 20m 12s	remaining: 52.6s
# 95839:	learn: 0.9931384	total: 20m 12s	remaining: 52.6s
# 95840:	learn: 0.9931384	total: 20m 12s	remaining: 52.6s
# 95841:	learn: 0.9931384	total: 20m 12s	remaining: 52.6s
# 95842:	learn: 0.9931384	total: 20m 12s	remaining: 52.6s
# 95843:	learn: 0.9931384	total: 20m 12s	remaining: 52.6s
# 95844:	learn: 0.9931384	total: 20m 12s	remaining: 52.6s
# 95845:	learn: 0.9931384	total: 20m 12s	remaining: 52.6s
# 95846:	learn: 0.9931384	total: 20m 12s	remaining: 52.5s
# 95847:	learn: 0.9931384	total: 20m 12s	remaining: 52.5s
# 95848:	learn: 0.9931384	total: 20m 12s	remaining: 52.5s
# 95849:	learn: 0.9931384	total: 20m 12s	remaining: 52.5s
# 95850:	learn: 0.9931384	total: 20m 12s	remaining: 52.5s
# 95851:	learn: 0.9931384	total: 20m 12s	remaining: 52.5s
# 95852:	learn: 0.9931384	total: 20m 12s	remaining: 52.5s
# 95853:	learn: 0.9931384	total: 20m 12s	remaining: 52.5s
# 95854:	learn: 0.9931384	total: 20m 12s	remaining: 52.4s
# 95855:	learn: 0.9931384	total: 20m 12s	remaining: 52.4s
# 95856:	learn: 0.9931384	total: 20m 12s	remaining: 52.4s
# 95857:	learn: 0.9931384	total: 20m 12s	remaining: 52.4s
# 95858:	learn: 0.9931384	total: 20m 12s	remaining: 52.4s
# 95859:	learn: 0.9931384	total: 20m 12s	remaining: 52.4s
# 95860:	learn: 0.9931384	total: 20m 12s	remaining: 52.4s
# 95861:	learn: 0.9931384	total: 20m 12s	remaining: 52.4s
# 95862:	learn: 0.9931384	total: 20m 12s	remaining: 52.3s
# 95863:	learn: 0.9931384	total: 20m 12s	remaining: 52.3s
# 95864:	learn: 0.9931384	total: 20m 12s	remaining: 52.3s
# 95865:	learn: 0.9931384	total: 20m 12s	remaining: 52.3s
# 95866:	learn: 0.9931384	total: 20m 13s	remaining: 52.3s
# 95867:	learn: 0.9931384	total: 20m 13s	remaining: 52.3s
# 95868:	learn: 0.9931384	total: 20m 13s	remaining: 52.3s
# 95869:	learn: 0.9931384	total: 20m 13s	remaining: 52.3s
# 95870:	learn: 0.9931384	total: 20m 13s	remaining: 52.2s
# 95871:	learn: 0.9931384	total: 20m 13s	remaining: 52.2s
# 95872:	learn: 0.9931384	total: 20m 13s	remaining: 52.2s
# 95873:	learn: 0.9931384	total: 20m 13s	remaining: 52.2s
# ...
# 99709:	learn: 0.9933932	total: 21m 1s	remaining: 3.67s
# 99710:	learn: 0.9933932	total: 21m 1s	remaining: 3.65s
# 99711:	learn: 0.9933932	total: 21m 1s	remaining: 3.64s
# 99712:	learn: 0.9933932	total: 21m 1s	remaining: 3.63s
# 99713:	learn: 0.9933932	total: 21m 1s	remaining: 3.62s
# 99714:	learn: 0.9933932	total: 21m 1s	remaining: 3.6s
# 99715:	learn: 0.9933932	total: 21m 1s	remaining: 3.59s
# 99716:	learn: 0.9933932	total: 21m 1s	remaining: 3.58s
# 99717:	learn: 0.9933932	total: 21m 1s	remaining: 3.57s
# 99718:	learn: 0.9933932	total: 21m 1s	remaining: 3.55s
# 99719:	learn: 0.9933932	total: 21m 1s	remaining: 3.54s
# 99720:	learn: 0.9933932	total: 21m 1s	remaining: 3.53s
# 99721:	learn: 0.9933932	total: 21m 1s	remaining: 3.52s
# 99722:	learn: 0.9933932	total: 21m 1s	remaining: 3.5s
# 99723:	learn: 0.9933932	total: 21m 1s	remaining: 3.49s
# 99724:	learn: 0.9933932	total: 21m 1s	remaining: 3.48s
# 99725:	learn: 0.9933932	total: 21m 1s	remaining: 3.46s
# 99726:	learn: 0.9933932	total: 21m 1s	remaining: 3.45s
# 99727:	learn: 0.9933932	total: 21m 1s	remaining: 3.44s
# 99728:	learn: 0.9933932	total: 21m 1s	remaining: 3.43s
# 99729:	learn: 0.9933932	total: 21m 1s	remaining: 3.41s
# 99730:	learn: 0.9933932	total: 21m 1s	remaining: 3.4s
# 99731:	learn: 0.9933932	total: 21m 1s	remaining: 3.39s
# 99732:	learn: 0.9933932	total: 21m 1s	remaining: 3.38s
# 99733:	learn: 0.9933932	total: 21m 1s	remaining: 3.36s
# 99734:	learn: 0.9933932	total: 21m 1s	remaining: 3.35s
# 99735:	learn: 0.9933932	total: 21m 1s	remaining: 3.34s
# 99736:	learn: 0.9933932	total: 21m 1s	remaining: 3.33s
# 99737:	learn: 0.9933932	total: 21m 1s	remaining: 3.31s
# 99738:	learn: 0.9933932	total: 21m 1s	remaining: 3.3s
# 99739:	learn: 0.9933932	total: 21m 1s	remaining: 3.29s
# 99740:	learn: 0.9933932	total: 21m 1s	remaining: 3.27s
# 99741:	learn: 0.9933932	total: 21m 1s	remaining: 3.26s
# 99742:	learn: 0.9933932	total: 21m 1s	remaining: 3.25s
# 99743:	learn: 0.9933932	total: 21m 1s	remaining: 3.24s
# 99744:	learn: 0.9933932	total: 21m 1s	remaining: 3.23s
# 99745:	learn: 0.9933932	total: 21m 1s	remaining: 3.21s
# 99746:	learn: 0.9933932	total: 21m 1s	remaining: 3.2s
# 99747:	learn: 0.9933932	total: 21m 1s	remaining: 3.19s
# 99748:	learn: 0.9933932	total: 21m 1s	remaining: 3.17s
# 99749:	learn: 0.9933932	total: 21m 1s	remaining: 3.16s
# 99750:	learn: 0.9933932	total: 21m 1s	remaining: 3.15s
# 99751:	learn: 0.9933932	total: 21m 1s	remaining: 3.14s
# 99752:	learn: 0.9933932	total: 21m 1s	remaining: 3.12s
# 99753:	learn: 0.9933932	total: 21m 1s	remaining: 3.11s
# 99754:	learn: 0.9933932	total: 21m 1s	remaining: 3.1s
# 99755:	learn: 0.9933932	total: 21m 1s	remaining: 3.09s
# 99756:	learn: 0.9933932	total: 21m 1s	remaining: 3.07s
# 99757:	learn: 0.9933932	total: 21m 1s	remaining: 3.06s
# 99758:	learn: 0.9933932	total: 21m 1s	remaining: 3.05s
# 99759:	learn: 0.9933932	total: 21m 1s	remaining: 3.04s
# 99760:	learn: 0.9933932	total: 21m 1s	remaining: 3.02s
# 99761:	learn: 0.9933932	total: 21m 1s	remaining: 3.01s
# 99762:	learn: 0.9933932	total: 21m 1s	remaining: 3s
# 99763:	learn: 0.9933932	total: 21m 1s	remaining: 2.98s
# 99764:	learn: 0.9933932	total: 21m 1s	remaining: 2.97s
# 99765:	learn: 0.9933932	total: 21m 1s	remaining: 2.96s
# 99766:	learn: 0.9933932	total: 21m 1s	remaining: 2.95s
# 99767:	learn: 0.9933932	total: 21m 1s	remaining: 2.93s
# 99768:	learn: 0.9933932	total: 21m 1s	remaining: 2.92s
# 99769:	learn: 0.9933932	total: 21m 1s	remaining: 2.91s
# 99770:	learn: 0.9933932	total: 21m 1s	remaining: 2.9s
# 99771:	learn: 0.9933932	total: 21m 1s	remaining: 2.88s
# 99772:	learn: 0.9933932	total: 21m 1s	remaining: 2.87s
# 99773:	learn: 0.9933932	total: 21m 1s	remaining: 2.86s
# 99774:	learn: 0.9933932	total: 21m 1s	remaining: 2.85s
# 99775:	learn: 0.9933932	total: 21m 1s	remaining: 2.83s
# 99776:	learn: 0.9933932	total: 21m 1s	remaining: 2.82s
# 99777:	learn: 0.9933932	total: 21m 1s	remaining: 2.81s
# 99778:	learn: 0.9933932	total: 21m 1s	remaining: 2.79s
# 99779:	learn: 0.9933932	total: 21m 2s	remaining: 2.78s
# 99780:	learn: 0.9933932	total: 21m 2s	remaining: 2.77s
# 99781:	learn: 0.9933932	total: 21m 2s	remaining: 2.76s
# 99782:	learn: 0.9933932	total: 21m 2s	remaining: 2.74s
# 99783:	learn: 0.9933932	total: 21m 2s	remaining: 2.73s
# 99784:	learn: 0.9933932	total: 21m 2s	remaining: 2.72s
# 99785:	learn: 0.9933932	total: 21m 2s	remaining: 2.71s
# 99786:	learn: 0.9933932	total: 21m 2s	remaining: 2.69s
# 99787:	learn: 0.9933932	total: 21m 2s	remaining: 2.68s
# 99788:	learn: 0.9933932	total: 21m 2s	remaining: 2.67s
# 99789:	learn: 0.9933932	total: 21m 2s	remaining: 2.66s
# 99790:	learn: 0.9933932	total: 21m 2s	remaining: 2.64s
# 99791:	learn: 0.9933932	total: 21m 2s	remaining: 2.63s
# 99792:	learn: 0.9933932	total: 21m 2s	remaining: 2.62s
# 99793:	learn: 0.9933932	total: 21m 2s	remaining: 2.6s
# 99794:	learn: 0.9933932	total: 21m 2s	remaining: 2.59s
# 99795:	learn: 0.9933932	total: 21m 2s	remaining: 2.58s
# 99796:	learn: 0.9933932	total: 21m 2s	remaining: 2.57s
# 99797:	learn: 0.9933932	total: 21m 2s	remaining: 2.55s
# 99798:	learn: 0.9933932	total: 21m 2s	remaining: 2.54s
# 99799:	learn: 0.9933932	total: 21m 2s	remaining: 2.53s
# 99800:	learn: 0.9933932	total: 21m 2s	remaining: 2.52s
# 99801:	learn: 0.9933932	total: 21m 2s	remaining: 2.5s
# 99802:	learn: 0.9933932	total: 21m 2s	remaining: 2.49s
# 99803:	learn: 0.9933932	total: 21m 2s	remaining: 2.48s
# 99804:	learn: 0.9933932	total: 21m 2s	remaining: 2.47s
# 99805:	learn: 0.9933932	total: 21m 2s	remaining: 2.45s
# 99806:	learn: 0.9933932	total: 21m 2s	remaining: 2.44s
# 99807:	learn: 0.9933932	total: 21m 2s	remaining: 2.43s
# 99808:	learn: 0.9933932	total: 21m 2s	remaining: 2.42s
# 99809:	learn: 0.9933932	total: 21m 2s	remaining: 2.4s
# 99810:	learn: 0.9933932	total: 21m 2s	remaining: 2.39s
# 99811:	learn: 0.9933932	total: 21m 2s	remaining: 2.38s
# 99812:	learn: 0.9933932	total: 21m 2s	remaining: 2.37s
# 99813:	learn: 0.9933932	total: 21m 2s	remaining: 2.35s
# 99814:	learn: 0.9933932	total: 21m 2s	remaining: 2.34s
# 99815:	learn: 0.9933932	total: 21m 2s	remaining: 2.33s
# 99816:	learn: 0.9933932	total: 21m 2s	remaining: 2.31s
# 99817:	learn: 0.9933932	total: 21m 2s	remaining: 2.3s
# 99818:	learn: 0.9933932	total: 21m 2s	remaining: 2.29s
# 99819:	learn: 0.9933932	total: 21m 2s	remaining: 2.28s
# 99820:	learn: 0.9933932	total: 21m 2s	remaining: 2.26s
# 99821:	learn: 0.9933932	total: 21m 2s	remaining: 2.25s
# 99822:	learn: 0.9933932	total: 21m 2s	remaining: 2.24s
# 99823:	learn: 0.9933932	total: 21m 2s	remaining: 2.23s
# 99824:	learn: 0.9933932	total: 21m 2s	remaining: 2.21s
# 99825:	learn: 0.9933932	total: 21m 2s	remaining: 2.2s
# 99826:	learn: 0.9933932	total: 21m 2s	remaining: 2.19s
# 99827:	learn: 0.9933932	total: 21m 2s	remaining: 2.17s
# 99828:	learn: 0.9933932	total: 21m 2s	remaining: 2.16s
# 99829:	learn: 0.9933932	total: 21m 2s	remaining: 2.15s
# 99830:	learn: 0.9933932	total: 21m 2s	remaining: 2.14s
# 99831:	learn: 0.9933932	total: 21m 2s	remaining: 2.12s
# 99832:	learn: 0.9933932	total: 21m 2s	remaining: 2.11s
# 99833:	learn: 0.9933932	total: 21m 2s	remaining: 2.1s
# 99834:	learn: 0.9933932	total: 21m 2s	remaining: 2.09s
# 99835:	learn: 0.9933932	total: 21m 2s	remaining: 2.07s
# 99836:	learn: 0.9933932	total: 21m 2s	remaining: 2.06s
# 99837:	learn: 0.9933932	total: 21m 2s	remaining: 2.05s
# 99838:	learn: 0.9933932	total: 21m 2s	remaining: 2.04s
# 99839:	learn: 0.9933932	total: 21m 2s	remaining: 2.02s
# 99840:	learn: 0.9933932	total: 21m 2s	remaining: 2.01s
# 99841:	learn: 0.9933932	total: 21m 2s	remaining: 2s
# 99842:	learn: 0.9933932	total: 21m 2s	remaining: 1.99s
# 99843:	learn: 0.9933932	total: 21m 2s	remaining: 1.97s
# 99844:	learn: 0.9933932	total: 21m 2s	remaining: 1.96s
# 99845:	learn: 0.9933932	total: 21m 2s	remaining: 1.95s
# 99846:	learn: 0.9933932	total: 21m 2s	remaining: 1.94s
# 99847:	learn: 0.9933932	total: 21m 2s	remaining: 1.92s
# 99848:	learn: 0.9933932	total: 21m 2s	remaining: 1.91s
# 99849:	learn: 0.9933932	total: 21m 2s	remaining: 1.9s
# 99850:	learn: 0.9933932	total: 21m 2s	remaining: 1.88s
# 99851:	learn: 0.9933932	total: 21m 2s	remaining: 1.87s
# 99852:	learn: 0.9933932	total: 21m 2s	remaining: 1.86s
# 99853:	learn: 0.9933932	total: 21m 2s	remaining: 1.85s
# 99854:	learn: 0.9933932	total: 21m 2s	remaining: 1.83s
# 99855:	learn: 0.9933932	total: 21m 2s	remaining: 1.82s
# 99856:	learn: 0.9933932	total: 21m 2s	remaining: 1.81s
# 99857:	learn: 0.9933932	total: 21m 2s	remaining: 1.79s
# 99858:	learn: 0.9933932	total: 21m 3s	remaining: 1.78s
# 99859:	learn: 0.9933932	total: 21m 3s	remaining: 1.77s
# 99860:	learn: 0.9933932	total: 21m 3s	remaining: 1.76s
# 99861:	learn: 0.9933932	total: 21m 3s	remaining: 1.75s
# 99862:	learn: 0.9933932	total: 21m 3s	remaining: 1.73s
# 99863:	learn: 0.9933932	total: 21m 3s	remaining: 1.72s
# 99864:	learn: 0.9933932	total: 21m 3s	remaining: 1.71s
# 99865:	learn: 0.9933932	total: 21m 3s	remaining: 1.69s
# 99866:	learn: 0.9933932	total: 21m 3s	remaining: 1.68s
# 99867:	learn: 0.9933932	total: 21m 3s	remaining: 1.67s
# 99868:	learn: 0.9933932	total: 21m 3s	remaining: 1.66s
# 99869:	learn: 0.9933932	total: 21m 3s	remaining: 1.64s
# 99870:	learn: 0.9933932	total: 21m 3s	remaining: 1.63s
# 99871:	learn: 0.9933932	total: 21m 3s	remaining: 1.62s
# 99872:	learn: 0.9933932	total: 21m 3s	remaining: 1.61s
# 99873:	learn: 0.9933932	total: 21m 3s	remaining: 1.59s
# 99874:	learn: 0.9933932	total: 21m 3s	remaining: 1.58s
# 99875:	learn: 0.9933932	total: 21m 3s	remaining: 1.57s
# 99876:	learn: 0.9933932	total: 21m 3s	remaining: 1.55s
# 99877:	learn: 0.9933932	total: 21m 3s	remaining: 1.54s
# 99878:	learn: 0.9933932	total: 21m 3s	remaining: 1.53s
# 99879:	learn: 0.9933932	total: 21m 3s	remaining: 1.52s
# 99880:	learn: 0.9933932	total: 21m 3s	remaining: 1.5s
# 99881:	learn: 0.9933932	total: 21m 3s	remaining: 1.49s
# 99882:	learn: 0.9933932	total: 21m 3s	remaining: 1.48s
# 99883:	learn: 0.9933932	total: 21m 3s	remaining: 1.47s
# 99884:	learn: 0.9933932	total: 21m 3s	remaining: 1.45s
# 99885:	learn: 0.9933932	total: 21m 3s	remaining: 1.44s
# 99886:	learn: 0.9933932	total: 21m 3s	remaining: 1.43s
# 99887:	learn: 0.9933932	total: 21m 3s	remaining: 1.42s
# 99888:	learn: 0.9933932	total: 21m 3s	remaining: 1.4s
# 99889:	learn: 0.9933932	total: 21m 3s	remaining: 1.39s
# 99890:	learn: 0.9933932	total: 21m 3s	remaining: 1.38s
# 99891:	learn: 0.9933932	total: 21m 3s	remaining: 1.36s
# 99892:	learn: 0.9933932	total: 21m 3s	remaining: 1.35s
# 99893:	learn: 0.9933932	total: 21m 3s	remaining: 1.34s
# 99894:	learn: 0.9933932	total: 21m 3s	remaining: 1.33s
# 99895:	learn: 0.9933932	total: 21m 3s	remaining: 1.31s
# 99896:	learn: 0.9933932	total: 21m 3s	remaining: 1.3s
# 99897:	learn: 0.9933932	total: 21m 3s	remaining: 1.29s
# 99898:	learn: 0.9933932	total: 21m 3s	remaining: 1.28s
# 99899:	learn: 0.9933932	total: 21m 3s	remaining: 1.26s
# 99900:	learn: 0.9933932	total: 21m 3s	remaining: 1.25s
# 99901:	learn: 0.9933932	total: 21m 3s	remaining: 1.24s
# 99902:	learn: 0.9933932	total: 21m 3s	remaining: 1.23s
# 99903:	learn: 0.9933932	total: 21m 3s	remaining: 1.21s
# 99904:	learn: 0.9933932	total: 21m 3s	remaining: 1.2s
# 99905:	learn: 0.9933932	total: 21m 3s	remaining: 1.19s
# 99906:	learn: 0.9933932	total: 21m 3s	remaining: 1.18s
# 99907:	learn: 0.9933932	total: 21m 3s	remaining: 1.16s
# 99908:	learn: 0.9933932	total: 21m 3s	remaining: 1.15s
# 99909:	learn: 0.9933932	total: 21m 3s	remaining: 1.14s
# 99910:	learn: 0.9933932	total: 21m 3s	remaining: 1.13s
# 99911:	learn: 0.9933932	total: 21m 3s	remaining: 1.11s
# 99912:	learn: 0.9933932	total: 21m 3s	remaining: 1.1s
# 99913:	learn: 0.9933932	total: 21m 3s	remaining: 1.09s
# 99914:	learn: 0.9933932	total: 21m 3s	remaining: 1.07s
# 99915:	learn: 0.9933932	total: 21m 3s	remaining: 1.06s
# 99916:	learn: 0.9933932	total: 21m 3s	remaining: 1.05s
# 99917:	learn: 0.9933932	total: 21m 3s	remaining: 1.04s
# 99918:	learn: 0.9933932	total: 21m 3s	remaining: 1.02s
# 99919:	learn: 0.9933932	total: 21m 3s	remaining: 1.01s
# 99920:	learn: 0.9933932	total: 21m 3s	remaining: 999ms
# 99921:	learn: 0.9933932	total: 21m 3s	remaining: 987ms
# 99922:	learn: 0.9933932	total: 21m 3s	remaining: 974ms
# 99923:	learn: 0.9933932	total: 21m 3s	remaining: 961ms
# 99924:	learn: 0.9933932	total: 21m 3s	remaining: 949ms
# 99925:	learn: 0.9933932	total: 21m 3s	remaining: 936ms
# 99926:	learn: 0.9933932	total: 21m 3s	remaining: 923ms
# 99927:	learn: 0.9933932	total: 21m 3s	remaining: 911ms
# 99928:	learn: 0.9933932	total: 21m 3s	remaining: 898ms
# 99929:	learn: 0.9933932	total: 21m 3s	remaining: 885ms
# 99930:	learn: 0.9933932	total: 21m 3s	remaining: 873ms
# 99931:	learn: 0.9933932	total: 21m 3s	remaining: 860ms
# 99932:	learn: 0.9933932	total: 21m 3s	remaining: 847ms
# 99933:	learn: 0.9933932	total: 21m 3s	remaining: 835ms
# 99934:	learn: 0.9933932	total: 21m 3s	remaining: 822ms
# 99935:	learn: 0.9933932	total: 21m 3s	remaining: 809ms
# 99936:	learn: 0.9933932	total: 21m 3s	remaining: 797ms
# 99937:	learn: 0.9933932	total: 21m 4s	remaining: 784ms
# 99938:	learn: 0.9933932	total: 21m 4s	remaining: 772ms
# 99939:	learn: 0.9933932	total: 21m 4s	remaining: 759ms
# 99940:	learn: 0.9933932	total: 21m 4s	remaining: 746ms
# 99941:	learn: 0.9933932	total: 21m 4s	remaining: 734ms
# 99942:	learn: 0.9933932	total: 21m 4s	remaining: 721ms
# 99943:	learn: 0.9933932	total: 21m 4s	remaining: 708ms
# 99944:	learn: 0.9933932	total: 21m 4s	remaining: 696ms
# 99945:	learn: 0.9933932	total: 21m 4s	remaining: 683ms
# 99946:	learn: 0.9933932	total: 21m 4s	remaining: 670ms
# 99947:	learn: 0.9933932	total: 21m 4s	remaining: 658ms
# 99948:	learn: 0.9933932	total: 21m 4s	remaining: 645ms
# 99949:	learn: 0.9933932	total: 21m 4s	remaining: 632ms
# 99950:	learn: 0.9933932	total: 21m 4s	remaining: 620ms
# 99951:	learn: 0.9933932	total: 21m 4s	remaining: 607ms
# 99952:	learn: 0.9933932	total: 21m 4s	remaining: 594ms
# 99953:	learn: 0.9933932	total: 21m 4s	remaining: 582ms
# 99954:	learn: 0.9933932	total: 21m 4s	remaining: 569ms
# 99955:	learn: 0.9933932	total: 21m 4s	remaining: 557ms
# 99956:	learn: 0.9933932	total: 21m 4s	remaining: 544ms
# 99957:	learn: 0.9933932	total: 21m 4s	remaining: 531ms
# 99958:	learn: 0.9933932	total: 21m 4s	remaining: 519ms
# 99959:	learn: 0.9933932	total: 21m 4s	remaining: 506ms
# 99960:	learn: 0.9933932	total: 21m 4s	remaining: 493ms
# 99961:	learn: 0.9933932	total: 21m 4s	remaining: 481ms
# 99962:	learn: 0.9933932	total: 21m 4s	remaining: 468ms
# 99963:	learn: 0.9933932	total: 21m 4s	remaining: 455ms
# 99964:	learn: 0.9933932	total: 21m 4s	remaining: 443ms
# 99965:	learn: 0.9933932	total: 21m 4s	remaining: 430ms
# 99966:	learn: 0.9933932	total: 21m 4s	remaining: 417ms
# 99967:	learn: 0.9933932	total: 21m 4s	remaining: 405ms
# 99968:	learn: 0.9933932	total: 21m 4s	remaining: 392ms
# 99969:	learn: 0.9933932	total: 21m 4s	remaining: 379ms
# 99970:	learn: 0.9933932	total: 21m 4s	remaining: 367ms
# 99971:	learn: 0.9933932	total: 21m 4s	remaining: 354ms
# 99972:	learn: 0.9933932	total: 21m 4s	remaining: 341ms
# 99973:	learn: 0.9933932	total: 21m 4s	remaining: 329ms
# 99974:	learn: 0.9933932	total: 21m 4s	remaining: 316ms
# 99975:	learn: 0.9933932	total: 21m 4s	remaining: 304ms
# 99976:	learn: 0.9933932	total: 21m 4s	remaining: 291ms
# 99977:	learn: 0.9933932	total: 21m 4s	remaining: 278ms
# 99978:	learn: 0.9933932	total: 21m 4s	remaining: 266ms
# 99979:	learn: 0.9933932	total: 21m 4s	remaining: 253ms
# 99980:	learn: 0.9933932	total: 21m 4s	remaining: 240ms
# 99981:	learn: 0.9933932	total: 21m 4s	remaining: 228ms
# 99982:	learn: 0.9933932	total: 21m 4s	remaining: 215ms
# 99983:	learn: 0.9933932	total: 21m 4s	remaining: 202ms
# 99984:	learn: 0.9933932	total: 21m 4s	remaining: 190ms
# 99985:	learn: 0.9933932	total: 21m 4s	remaining: 177ms
# 99986:	learn: 0.9933932	total: 21m 4s	remaining: 164ms
# 99987:	learn: 0.9933932	total: 21m 4s	remaining: 152ms
# 99988:	learn: 0.9933932	total: 21m 4s	remaining: 139ms
# 99989:	learn: 0.9933932	total: 21m 4s	remaining: 126ms
# 99990:	learn: 0.9933932	total: 21m 4s	remaining: 114ms
# 99991:	learn: 0.9933932	total: 21m 4s	remaining: 101ms
# 99992:	learn: 0.9933932	total: 21m 4s	remaining: 88.5ms
# 99993:	learn: 0.9933932	total: 21m 4s	remaining: 75.9ms
# 99994:	learn: 0.9933932	total: 21m 4s	remaining: 63.2ms
# 99995:	learn: 0.9933932	total: 21m 4s	remaining: 50.6ms
# 99996:	learn: 0.9933932	total: 21m 4s	remaining: 37.9ms
# 99997:	learn: 0.9933932	total: 21m 4s	remaining: 25.3ms
# 99998:	learn: 0.9933932	total: 21m 4s	remaining: 12.6ms
# 99999:	learn: 0.9933932	total: 21m 4s	remaining: 0us

# %%
predictions_1 = model.predict(test_features_df)
np.unique(predictions_1 , return_counts=True)
# Out:
# (array([0, 1]), array([ 422, 8154]))

# %%
submission_df = pd.read_csv(folderPath+"predications_submission.csv", 
                            index_col="tripid")

np.testing.assert_array_equal(test_features_df.index.values, 
                              submission_df.index.values)

submission_df['prediction'] = predictions_1

submission_df.to_csv(folderPath+'predictions/new/13_all_null_filled_100000epochs.csv')
